# %%
r2_scores = {
    'Hybrid Linear Regression': 0.7580,
    'SVD': 0.0602,
    'Aspect Based Sentiment Aware Model': 0.7440,
    'Neural MF': 0.248972
}

model_metrics = {
    'Hybrid Linear Regression': {'rmse': 0.5418, 'mae': 0.3754, 'r2': 0.7580},
    'SVD':     {'rmse': 0.9636, 'mae': 0.7279, 'r2': 0.0602},
    'Aspect Based Sentiment Aware Model':           {'rmse': 0.7440, 'mae': 0.3862, 'r2': 0.7440},
    'Neural MF':      {'rmse': 0.9542, 'mae': 0.7135, 'r2': 0.248972}
}

# %%
import matplotlib.pyplot as plt

models = list(model_metrics.keys())
rmse = [model_metrics[m]['rmse'] for m in models]
mae  = [model_metrics[m]['mae']  for m in models]
r2   = [model_metrics[m]['r2']   for m in models]

# --- Plot RMSE ---
plt.figure(figsize=(8, 5))
plt.bar(models, rmse, color='lightcoral')
plt.ylabel("RMSE")
plt.title("Root Mean Squared Error by Model")
plt.grid(axis='y')
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# --- Plot MAE ---
plt.figure(figsize=(8, 5))
plt.bar(models, mae, color='mediumseagreen')
plt.ylabel("MAE")
plt.title("Mean Absolute Error by Model")
plt.grid(axis='y')
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()

# --- Plot R² ---
plt.figure(figsize=(8, 5))
plt.bar(models, r2, color='cornflowerblue')
plt.ylabel("R² Score")
plt.ylim(0, 1.0)
plt.title("R² Score by Model")
plt.grid(axis='y')
plt.xticks(rotation=15)
plt.tight_layout()
plt.show()
